# %%
#importing pandas library
import pandas as pd

# %%
# reading the csv and coverting to dataframe 
df=pd.read_csv('Desktop/Sales_Data/Sales_April_2019.csv')

# %%
#printing the dataframe
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
# Descriptive statistics of all columns
df.describe()
# Out:
#         Order ID                   Product Quantity Ordered Price Each  \
# count      18324                     18324            18324      18324
# unique     17538                        20                8         19
# top     Order ID  Lightning Charging Cable                1      14.95
# freq          35                      2201            16558       2201
#
#         Order Date  Purchase Address
# count        18324             18324
# unique       13584             17120
# top     Order Date  Purchase Address
# freq            35                35

# %%
# get the shape of dataframe
df.shape
# Out:
# (18383, 6)

# %%
# to get no of rows in a dataframe
len(df)
# Out:
# 18383

# %%
# to get no of unqiue values in each column
df.nunique()
# Out:
# Order ID            17538
# Product                20
# Quantity Ordered        8
# Price Each             19
# Order Date          13584
# Purchase Address    17120
# dtype: int64

# %%
# function is used to get series containing counts of unique values
df['Product'].value_counts()
# Out:
# Lightning Charging Cable      2201
# USB-C Charging Cable          2079
# AA Batteries (4-pack)         2063
# AAA Batteries (4-pack)        1989
# Wired Headphones              1890
# Apple Airpods Headphones      1515
# Bose SoundSport Headphones    1280
# 27in FHD Monitor               734
# iPhone                         693
# 34in Ultrawide Monitor         650
# Google Phone                   581
# 27in 4K Gaming Monitor         563
# Flatscreen TV                  458
# Macbook Pro Laptop             453
# ThinkPad Laptop                392
# 20in Monitor                   390
# Vareebadd Phone                220
# LG Dryer                        77
# LG Washing Machine              61
# Product                         35
# Name: Product, dtype: int64

# %%
# get the first five rows of dataframe
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# get the last five rows of dataframe
df.tail()
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215

# %%
# concatenating all the csv files and making a new csv file 
import os
df=pd.read_csv('Desktop/Sales_Data/Sales_April_2019.csv')
files=[file for file in os.listdir('Desktop/Sales_Data')]
all_data=pd.DataFrame()
for file in files:
    df=pd.read_csv('Desktop/Sales_Data/'+file)
    all_data=pd.concat([all_data,df])
all_data.head()
all_data.to_csv('Desktop/all_month.csv')

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# to get no of rows in a data
len(all_data)
# Out:
# 186850

# %%
# to get the datatype of columns
all_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
# to get the information of dataframe
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
# renaming the column values
all_data.columns=all_data.columns.str.replace(' ','_')

# %%
all_data
# Out:
#       Order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order_Date                         Purchase_Address
# ...

# %%
# check for dataframe contains nullvalue or not
all_data.isnull().any()
# Out:
# Order_ID            True
# Product             True
# Quantity_Ordered    True
# Price_Each          True
# Order_Date          True
# Purchase_Address    True
# dtype: bool

# %%
# we have null values in the dataframe if we want to remove the missing values
all_data=all_data.dropna(axis=0,how='all')

# %%
## check for dataframe contains nullvalue or not
all_data.isnull().any()
# Out:
# Order_ID            False
# Product             False
# Quantity_Ordered    False
# Price_Each          False
# Order_Date          False
# Purchase_Address    False
# dtype: bool

# %%
# change the datatype of columns
all_data['Quantity_Ordered']=pd.to_numeric(all_data['Quantity_Ordered'],errors='coerce')
all_data['Price_Each']=pd.to_numeric(all_data['Price_Each'],errors='coerce')
# Out:
# <ipython-input-21-4d9f207b7b22>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity_Ordered']=pd.to_numeric(all_data['Quantity_Ordered'],errors='coerce')
# <ipython-input-21-4d9f207b7b22>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price_Each']=pd.to_numeric(all_data['Price_Each'],errors='coerce')

# %%
all_data.dtypes
# Out:
# Order_ID             object
# Product              object
# Quantity_Ordered    float64
# Price_Each          float64
# Order_Date           object
# Purchase_Address     object
# dtype: object

# %%
# to get the total sum of each product sold by customers
all_data.groupby('Product').sum()['Price_Each']
# Out:
# Product
# 20in Monitor                   451068.99
# 27in 4K Gaming Monitor        2429637.70
# 27in FHD Monitor              1125974.93
# 34in Ultrawide Monitor        2348718.19
# AA Batteries (4-pack)           79015.68
# AAA Batteries (4-pack)          61716.59
# Apple Airpods Headphones      2332350.00
# Bose SoundSport Headphones    1332366.75
# Flatscreen TV                 1440000.00
# Google Phone                  3315000.00
# LG Dryer                       387600.00
# LG Washing Machine             399600.00
# Lightning Charging Cable       323787.10
# Macbook Pro Laptop            8030800.00
# Product                             0.00
# ThinkPad Laptop               4127958.72
# USB-C Charging Cable           261740.85
# Vareebadd Phone                826000.00
# Wired Headphones               226395.18
# iPhone                        4789400.00
# Name: Price_Each, dtype: float64

# %%
# to get the count of each product sold by customers
all_data.groupby('Product').count()['Quantity_Ordered']
# Out:
# Product
# 20in Monitor                   4101
# 27in 4K Gaming Monitor         6230
# 27in FHD Monitor               7507
# 34in Ultrawide Monitor         6181
# AA Batteries (4-pack)         20577
# AAA Batteries (4-pack)        20641
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# Flatscreen TV                  4800
# Google Phone                   5525
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      21658
# Macbook Pro Laptop             4724
# Product                           0
# ThinkPad Laptop                4128
# USB-C Charging Cable          21903
# Vareebadd Phone                2065
# Wired Headphones              18882
# iPhone                         6842
# Name: Quantity_Ordered, dtype: int64

# %%
#creating a new column using slicing
all_data=all_data[all_data['Order_Date'].str[0:2]!='Or']
all_data['Month']=all_data['Order_Date'].str[0:2]
all_data['Month']=pd.to_numeric(all_data['Month'])
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#        Order_Date                      Purchase_Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
# total cost spend by customers for each order
all_data['Sales']=all_data['Quantity_Ordered']*all_data['Price_Each']

# %%
all_data
# Out:
#       Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0       176558        USB-C Charging Cable               2.0       11.95
# 2       176559  Bose SoundSport Headphones               1.0       99.99
# 3       176560                Google Phone               1.0      600.00
# 4       176560            Wired Headphones               1.0       11.99
# 5       176561            Wired Headphones               1.0       11.99
# ...        ...                         ...               ...         ...
# 11681   259353      AAA Batteries (4-pack)               3.0        2.99
# 11682   259354                      iPhone               1.0      700.00
# 11683   259355                      iPhone               1.0      700.00
# 11684   259356      34in Ultrawide Monitor               1.0      379.99
# 11685   259357        USB-C Charging Cable               1.0       11.95
#
#            Order_Date                         Purchase_Address  Month   Sales
# ...

# %%
# apply() Pandas. apply allow the users to pass a function and apply it on every single value of the Pandas series.
all_data['State']=all_data['Purchase_Address'].apply(lambda x:x.split(',')[2][0:3])

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#        Order_Date                      Purchase_Address  Month   Sales State
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90    TX
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99    MA
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00    CA
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99    CA
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99    CA

# %%
# apply() Pandas. apply allow the users to pass a function and apply it on every single value of the Pandas series.
all_data['Zipcode']=all_data['Purchase_Address'].apply(lambda x:x.split(',')[2][3:])

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#        Order_Date                      Purchase_Address  Month   Sales State  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90    TX
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99    MA
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00    CA
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99    CA
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99    CA
#
#   Zipcode
# 0   75001
# 2   02215
# 3   90001
# 4   90001
# 5   90001

# %%
# apply() Pandas. apply allow the users to pass a function and apply it on every single value of the Pandas series.
all_data['City']=all_data['Purchase_Address'].apply(lambda x:x.split(',')[1])

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#        Order_Date                      Purchase_Address  Month   Sales State  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90    TX
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99    MA
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00    CA
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99    CA
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99    CA
#
#   Zipcode          City
# 0   75001        Dallas
# 2   02215        Boston
# ...

# %%
# get the five state which has maximum sales
all_data.groupby('State').sum()['Sales'].sort_values(ascending=False).head()
# Out:
# State
#  CA    1.371477e+07
#  NY    4.664317e+06
#  TX    4.587557e+06
#  MA    3.661642e+06
#  GA    2.795499e+06
# Name: Sales, dtype: float64

# %%
# catgorical plot - bar plot for visualising sales for each state
state_group=all_data.groupby('State')
sales=state_group.sum()['Sales']
states=[state for state,df in state_group]
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14,7))
sns.barplot(states,sales)
plt.xticks(rotation='vertical')
plt.show()

# %%
# which month has maximum no of sales
all_data.groupby('Month').sum()['Sales']
# Out:
# Month
# 1     1.822257e+06
# 2     2.202022e+06
# 3     2.807100e+06
# 4     3.390670e+06
# 5     3.152607e+06
# 6     2.577802e+06
# 7     2.647776e+06
# 8     2.244468e+06
# 9     2.097560e+06
# 10    3.736727e+06
# 11    3.199603e+06
# 12    4.613443e+06
# Name: Sales, dtype: float64

# %%
# visualize which month has maximum no of sales
months=all_data.groupby('Month')
sales=months.count()['Sales']
all_months=[month for month,df in months]
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14,7))
sns.lineplot(all_months,sales,marker='o')
plt.xticks(all_months)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid()
plt.show()

# %%
# converting the datatype of Order_Date
all_data['Order_Date']=pd.to_datetime(all_data['Order_Date'])

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order_Date                      Purchase_Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#   State Zipcode          City
# 0    TX   75001        Dallas
# 2    MA   02215        Boston
# ...

# %%
# adding a new column data by using existing dataframe
all_data['Hour']=all_data['Order_Date'].dt.hour

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order_Date                      Purchase_Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#   State Zipcode          City  Hour
# 0    TX   75001        Dallas     8
# ...

# %%
# At what time we have maximum sales
all_data.groupby('Hour').sum()['Sales']
# Out:
# Hour
# 0      713721.27
# 1      460866.88
# 2      234851.44
# 3      145757.89
# 4      162661.01
# 5      230679.82
# 6      448113.00
# 7      744854.12
# 8     1192348.97
# 9     1639030.58
# 10    1944286.77
# 11    2300610.24
# 12    2316821.34
# 13    2155389.80
# 14    2083672.73
# 15    1941549.60
# 16    1904601.31
# 17    2129361.61
# 18    2219348.30
# 19    2412938.54
# 20    2281716.24
# 21    2042000.86
# 22    1607549.21
# 23    1179304.44
# Name: Sales, dtype: float64

# %%
# visualize the data at what time we have maximum sales
hours=all_data.groupby('Hour')
sales=hours.count()['Sales']
import matplotlib.pyplot as plt
all_hours=[h for h,df in hours]
plt.plot(all_hours,sales)
plt.xticks(all_hours)
plt.grid()
plt.show()

# %%
all_data['Order_ID'].value_counts()
# Out:
# 160873    5
# 263918    4
# 165665    4
# 312462    4
# 194253    4
#          ..
# 182541    1
# 258232    1
# 224349    1
# 317842    1
# 221011    1
# Name: Order_ID, Length: 178437, dtype: int64

# %%
# which product is sold most by customers
product_group=all_data.groupby('Product')
quantity=product_group.sum()['Quantity_Ordered']
products=[product for product,df in product_group]
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(products,quantity)
plt.xticks(rotation='vertical')
plt.xlabel('Product')
plt.ylabel('Quantity_Ordered')
plt.show()

# %%
# total sales for each month
sns.countplot(x='Month',data=all_data)

# %%
# total no of sales in the city dallas
all_data[all_data['City']==' Dallas'].count()['Sales']
# Out:
# 14820

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x='Product',y='Price_Each',data=df)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-03989ffab504> in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.barplot(x='Product',y='Price_Each',data=df)
#       4 plt.xticks(rotation='vertical')
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ...

# %%
# which zipcode have maximum sales
zip_code=all_data.groupby('Zipcode')
sales=zip_code.sum()['Sales']
z=[zipcode for zipcode,df in zip_code]
import matplotlib.pyplot as plt
import seaborn as sns
sns.lineplot(z,sales,marker='o')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order_Date                      Purchase_Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#   State Zipcode          City  Hour
# 0    TX   75001        Dallas     8
# ...

# %%
# how to rename the column name
all_data.rename(columns={'Zipcode':'Zip_code'},inplace=True)

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order_Date                      Purchase_Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#   State Zip_code          City  Hour
# 0    TX    75001        Dallas     8
# ...

# %%
# Extracting the minute from Order_Date and add it to a new column named minute
all_data['Minute']=all_data['Order_Date'].dt.minute

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order_Date                      Purchase_Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#   State Zip_code          City  Hour  Minute
# 0    TX    75001        Dallas     8      46
# ...

# %%
# how to drop a particular column
all_data.drop('Zip_code',axis=1,inplace=True)

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order_Date                      Purchase_Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#   State          City  Hour  Minute
# 0    TX        Dallas     8      46
# ...

# %%
# using the strip and using the and operotor
all_data['State']=all_data['State'].apply(lambda x:x.strip())
all_data[(all_data['Product']=='Google Phone') & (all_data['State']=='TX')]
# Out:
#       Order_ID       Product  Quantity_Ordered  Price_Each  \
# 190     176739  Google Phone               1.0       600.0
# 705     177228  Google Phone               1.0       600.0
# 1072    177578  Google Phone               1.0       600.0
# 2637    179083  Google Phone               1.0       600.0
# 2922    179357  Google Phone               1.0       600.0
# ...        ...           ...               ...         ...
# 10796   258514  Google Phone               1.0       600.0
# 10812   258528  Google Phone               1.0       600.0
# 11023   258729  Google Phone               1.0       600.0
# 11191   258890  Google Phone               1.0       600.0
# 11281   258976  Google Phone               1.0       600.0
#
#                Order_Date                   Purchase_Address  Month  Sales  \
# 190   2019-04-05 17:38:00       730 6th St, Austin, TX 73301      4  600.0
# 705   2019-04-17 19:38:00     233 South St, Dallas, TX 75001      4  600.0
# ...

# %%
all_data['City']=all_data['City'].apply(lambda x:x.strip())
all_data[(all_data['City']=='Dallas') & (all_data['Price_Each']>600)]
# Out:
#       Order_ID             Product  Quantity_Ordered  Price_Each  \
# 112     176665     ThinkPad Laptop               1.0      999.99
# 182     176732              iPhone               1.0      700.00
# 233     176781              iPhone               1.0      700.00
# 388     176929     ThinkPad Laptop               1.0      999.99
# 689     177213              iPhone               1.0      700.00
# ...        ...                 ...               ...         ...
# 10491   258218              iPhone               1.0      700.00
# 10537   258263              iPhone               1.0      700.00
# 11172   258872  Macbook Pro Laptop               1.0     1700.00
# 11187   258886     ThinkPad Laptop               1.0      999.99
# 11304   258998              iPhone               1.0      700.00
#
#                Order_Date                  Purchase_Address  Month    Sales  \
# 112   2019-04-07 14:15:00     927 13th St, Dallas, TX 75001      4   999.99
# ...

# %%
# sort the sales by descending order
all_data.sort_values(by='Sales',ascending=False)
# Out:
#       Order_ID                 Product  Quantity_Ordered  Price_Each  \
# 6776    200528      Macbook Pro Laptop               2.0     1700.00
# 385     210292      Macbook Pro Laptop               2.0     1700.00
# 4717    181069      Macbook Pro Laptop               2.0     1700.00
# 5219    181544      Macbook Pro Laptop               2.0     1700.00
# 20213   278637         ThinkPad Laptop               2.0      999.99
# ...        ...                     ...               ...         ...
# 6613    265671  AAA Batteries (4-pack)               1.0        2.99
# 6173    156382  AAA Batteries (4-pack)               1.0        2.99
# 6176    156385  AAA Batteries (4-pack)               1.0        2.99
# 6178    156387  AAA Batteries (4-pack)               1.0        2.99
# 1794    211621  AAA Batteries (4-pack)               1.0        2.99
#
#                Order_Date                       Purchase_Address  Month  \
# ...

# %%
# reset the index
all_data.reset_index(inplace=True,drop=True)

# %%
all_data.head()
# Out:
#   Order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 1   176559  Bose SoundSport Headphones               1.0       99.99
# 2   176560                Google Phone               1.0      600.00
# 3   176560            Wired Headphones               1.0       11.99
# 4   176561            Wired Headphones               1.0       11.99
#
#            Order_Date                      Purchase_Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#   State         City  Hour  Minute
# 0    TX       Dallas     8      46
# ...
